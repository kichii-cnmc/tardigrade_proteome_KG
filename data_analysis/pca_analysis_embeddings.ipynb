# %% [markdown]
# Used to determine the optimal number of dimensions for PCA reduction of embeddings

# %%
# imports
import argparse
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = np.load("../embeddings_test_pca.npz", allow_pickle=True)
embedding_dict = data['embedding_dict'].item()
print(f"Loaded {len(embedding_dict)} embeddings from file.")
